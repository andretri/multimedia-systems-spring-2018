# %%
# %matplotlib inline

from io import StringIO
from PIL import Image
import imageio
import numpy as np
import pylab
import matplotlib.pyplot as plt
import os

# %%
homer_vid = "resources/ex617/hall_monitor_cif.y4m"
resources_path = "resources/ex617"

# %%
def QuantizeVid(frames, Q=10):
    frames_q = []
    for frame in frames:
        frames_q.append(np.around(np.around(frame/Q, 2)*Q, 2))
    return frames_q

# %%
def QuantizeImage(img, Q=10):
    return np.around(np.around(img/Q, 2)*Q, 2)

# %%
def VidConvertGrayScale(rgbVid):
    '''Converts numpy array vid to BW vid'''
    frames_bw = []
    for frame in rgbVid:
        frames_bw.append(np.dot(frame[:,:,:3], [0.2989, 0.587, 0.114]))
    return np.array(frames_bw)

# %%
def parse_vid(filename):
    vid = imageio.get_reader(filename,  'ffmpeg')
    fps = vid.get_meta_data()['fps']
    num = 0
    frames = []
    while 1:
        try:
            image = vid.get_data(num)
            frames.append(image)
            num+=1
        except IndexError:
            break

    return np.array(frames), fps

# %%
def calc_diff(frames):
    dif_lst = []
    for i in range(1, frames.shape[0]):
        dif_lst.append(frames[i-1,:,:]-frames[i,:,:])
    return np.array(dif_lst)

# %%
def comp_vid(frames):
    enc_list= []
    for frame in frames:
        enc_list.append(comp_image(frame))
    return enc_list

# %%
def comp_image(frame):
    cnt = 0
    curr_el = frame[0,0]

    encoded = []

    for i in range(frame.shape[0]):
        for j in range(frame.shape[1]):
            if frame[i,j] == curr_el:
                cnt += 1
            else:
                encoded.append('{0}!{1}'.format(curr_el, cnt))
                curr_el = frame[i, j]
                cnt = 1        

    encoded.append('{0}!{1}'.format(curr_el, cnt))
    return encoded

# %%
def vid_encode(filename):
    # parse RGB video
    frames, fps = parse_vid(filename)
    # convert to BW
    bw_frames = VidConvertGrayScale(frames)
    # calculate the frame difference matrix
    diffs = calc_diff(bw_frames)
    # quantize the matrix
    q_diffs = QuantizeVid(diffs, Q=100)
    # compress quantized matrix and 1st frame
    q_diffs_comp = comp_vid(q_diffs)
    img1_q = QuantizeImage(bw_frames[0,:,:])
    first_img_comp = comp_image(img1_q)
    
    return first_img_comp, q_diffs_comp, bw_frames[0,:,:].shape, fps

# %%
def decode_vid(frames, dims):
    dec_list = []
    for frame in frames:    
        original_dimensions = dims
        decoded = []

        for i in frame:
            symbol, count = i.split('!')
            decoded.extend([float(symbol)]*int(count))   

        dec = np.array(decoded, dtype=np.float64).reshape(original_dimensions)
        dec_list.append(dec)
    return np.array(dec_list)

# %%
def decode_image(frame, dims):
    original_dimensions = dims
    decoded = []

    for i in frame:
        symbol, count = i.split('!')
        decoded.extend([float(symbol)]*int(count))   

    decoded = np.array(decoded, dtype=np.float64).reshape(original_dimensions)
    return np.array(decoded)

# %%
def reconstruct_vid(img1, diffs):
    final_vid  = [img1]
    cnt = 1
    for frame in diffs:
        final_vid.append(final_vid[-1]-frame)
        
    
    return np.array(final_vid)

# %%
def save_vid(frames, path, name, fps):
    writer = imageio.get_writer(os.path.join(path,name), fps=fps,mode="I")

    for frame in frames:
        writer.append_data(frame)
    writer.close()

# %%
import pickle

# %%
first_img_comp , q_diffs_comp, dims, fps = vid_encode(homer_vid)

#pickle.dump(os.path.join(resources_path,'img1.pckl'), first_img_comp)
#pickle.dump(os.path.join(resources_path,'qdiffs.pckl'), q_diffs_comp)

# %%
img1 = decode_image(first_img_comp, dims)
diffs = decode_vid(q_diffs_comp, dims)
tmp2 = reconstruct_vid(img1, diffs)

save_vid(tmp2,resources_path,'hall_final.mp4', fps)
# Out:
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [0.0, 255.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-0.4, 255.4]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-0.4, 255.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-0.5, 256.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-0.5999999999999996, 256.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2999999999999998, 256.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2999999999999998, 256.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.0, 257.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2999999999999998, 257.4]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2999999999999998, 257.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.5, 257.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.0, 257.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.0, 257.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.0, 258.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2999999999999998, 258.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.7, 258.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.8000000000000114, 258.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.8000000000000114, 258.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.3, 259.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.7, 259.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.7000000000000002, 258.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.0, 258.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.7, 259.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.3000000000000114, 259.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.0, 259.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.0, 259.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.7, 259.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.4000000000000057, 259.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.0999999999999996, 259.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.0999999999999996, 259.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.0, 260.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.0999999999999996, 260.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.5999999999999943, 260.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.0, 260.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.0999999999999996, 259.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.699999999999989, 260.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.0, 260.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.400000000000006, 260.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.0, 260.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.7, 260.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.0, 260.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.199999999999989, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.199999999999989, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 260.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.7, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.0, 261.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 261.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 261.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.100000000000001, 261.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 261.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 261.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.0, 261.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 261.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 261.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 261.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 261.1]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.8000000000000114, 261.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.7, 261.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.7, 261.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.0, 261.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 261.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.7, 262.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.7, 261.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.5, 262.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 262.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.5, 262.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.9000000000000057, 262.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 262.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.0, 262.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.7, 262.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 262.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.400000000000006, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.599999999999994, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.399999999999999, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 263.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 262.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 263.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 263.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.399999999999999, 263.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 264.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.399999999999999, 263.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.600000000000001, 263.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.5, 263.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.600000000000001, 263.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.399999999999999, 264.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.5, 264.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 263.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 264.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 265.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.0, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.300000000000011, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.600000000000001, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.7, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.400000000000006, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.600000000000001, 265.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.600000000000001, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.5, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.800000000000011, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.800000000000011, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.600000000000001, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.400000000000006, 267.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.600000000000001, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.400000000000006, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.400000000000006, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.099999999999994, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 265.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.600000000000001, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 265.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 267.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 265.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.199999999999989, 265.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 265.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 266.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 265.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.600000000000001, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 266.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.099999999999994, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.7, 266.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.7, 266.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.5, 265.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.199999999999989, 266.1]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.800000000000011, 266.1]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.800000000000011, 265.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.300000000000011, 266.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-11.300000000000011, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.300000000000011, 266.3]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-11.699999999999989, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.600000000000001, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.800000000000011, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.900000000000006, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.900000000000006, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.7, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.300000000000011, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.300000000000011, 266.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 266.9]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 266.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 266.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.399999999999999, 267.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.300000000000011, 267.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 267.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.699999999999999, 266.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.7, 267.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 267.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 267.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.400000000000006, 267.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.400000000000006, 267.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-11.600000000000001, 267.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.600000000000001, 268.5]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 267.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 267.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.7, 267.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 268.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 268.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 268.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 268.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.0, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.699999999999999, 269.0]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 268.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 269.2]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 268.6]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.600000000000001, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.699999999999989, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.600000000000001, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-11.600000000000001, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.699999999999999, 268.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.300000000000011, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-11.300000000000011, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.5, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.600000000000001, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.5, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.6, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-13.600000000000001, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.799999999999997, 270.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.0, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.699999999999989, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-12.600000000000001, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 269.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.600000000000001, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.600000000000001, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-13.600000000000001, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-12.5, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.5, 270.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-10.0, 270.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.0, 269.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.199999999999989, 270.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.699999999999989, 268.8]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-9.5, 271.7]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))

# %%
first_img_comp
# Out:
# array([[ 1,  1,  1, ..., 25, 25, 25],
#        [11, 18, 17, ..., 25, 25, 25],
#        [13, 24, 23, ..., 25, 25, 25],
#        ...,
#        [ 3,  6,  6, ..., 12, 10, 11],
#        [ 3,  6,  6, ...,  8,  6,  6],
#        [ 3,  7,  7, ...,  1,  0,  0]])
